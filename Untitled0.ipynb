# %% [markdown]
# <a href="https://colab.research.google.com/github/Bismarkoooo/computer-science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type(7) #typefunction()
# Out:
# int

# %%
type(16.2) #Numbers with decimals
# Out:
# float

# %%
type("Bismark") #Strings
# Out:
# str

# %%
type (True) #Boolean
# Out:
# bool

# %%
type (False)#Boolean
# Out:
# bool

# %%
#Variables
name ="Bismark", "Kim"
age = 18
city = "Eldoret"

# %%
print(name)
# Out:
# ('Bismark', 'Kim')

# %%
#Math in python
pi =355/113 #Approximate value for pi
radius= 2.2
area =pi*(radius**2)
circumference =pi*(2*radius)

# %%
float(60)
# Out:
# 60.0

# %%
int(99.9)
# Out:
# 99
